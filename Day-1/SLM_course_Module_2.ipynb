# %%
import os
import pandas as pd
from huggingface_hub import login, list_repo_files, hf_hub_download
from google.colab import userdata

# %%
# Authentication
hf_token = userdata.get('HF_TOKEN')
login(token=hf_token)

# Dataset configuration
repo_id = "ashtrayAI/Bangla_Financial_news_articles_Dataset"
folder = "Bangla_fin_news_articles"

# %%
# List all files
files = list_repo_files(repo_id=repo_id, repo_type="dataset", token=hf_token)
csv_files = [f for f in files if f.startswith(folder + "/") and f.endswith(".csv")]
print(f"Found {len(csv_files)} CSV files.")
# Out:
# Found 7695 CSV files.

# %%
# Download and load
dfs = []
for file in csv_files:
    local_path = hf_hub_download(
        repo_id=repo_id,
        filename=file,
        repo_type="dataset",
        token=hf_token
    )
    df = pd.read_csv(local_path)
    dfs.append(df)
    print(f"Loaded {file} into DataFrame.")

# Step 3: Combine
full_df = pd.concat(dfs, ignore_index=True)
print("Combined DataFrame shape:", full_df.shape)
# Out:
# Loaded Bangla_fin_news_articles/1.csv into DataFrame.
# Loaded Bangla_fin_news_articles/10.csv into DataFrame.
# Loaded Bangla_fin_news_articles/100.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1000.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1001.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1002.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1003.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1004.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1005.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1006.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1007.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1008.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1009.csv into DataFrame.
# Loaded Bangla_fin_news_articles/101.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1010.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1011.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1012.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1013.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1014.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1015.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1016.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1017.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1018.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1019.csv into DataFrame.
# Loaded Bangla_fin_news_articles/102.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1020.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1021.csv into DataFrame.
# Loaded Bangla_fin_news_articles/1022.csv into DataFrame.
# 1023.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1023.csv into DataFrame.
# 1024.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1024.csv into DataFrame.
# 1025.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1025.csv into DataFrame.
# 1026.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1026.csv into DataFrame.
# 1027.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1027.csv into DataFrame.
# 1028.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1028.csv into DataFrame.
# 1029.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1029.csv into DataFrame.
# 103.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/103.csv into DataFrame.
# 1030.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1030.csv into DataFrame.
# 1031.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1031.csv into DataFrame.
# 1032.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1032.csv into DataFrame.
# 1033.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1033.csv into DataFrame.
# 1034.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1034.csv into DataFrame.
# 1035.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1035.csv into DataFrame.
# 1036.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1036.csv into DataFrame.
# 1037.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1037.csv into DataFrame.
# 1038.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1038.csv into DataFrame.
# 1039.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1039.csv into DataFrame.
# 104.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/104.csv into DataFrame.
# 1040.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1040.csv into DataFrame.
# 1041.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1041.csv into DataFrame.
# 1042.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1042.csv into DataFrame.
# 1043.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1043.csv into DataFrame.
# 1044.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1044.csv into DataFrame.
# 1045.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1045.csv into DataFrame.
# 1046.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1046.csv into DataFrame.
# 1047.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1047.csv into DataFrame.
# 1048.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1048.csv into DataFrame.
# 1049.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1049.csv into DataFrame.
# 105.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/105.csv into DataFrame.
# 1050.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1050.csv into DataFrame.
# 1051.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1051.csv into DataFrame.
# 1052.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1052.csv into DataFrame.
# 1053.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1053.csv into DataFrame.
# 1054.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1054.csv into DataFrame.
# 1055.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1055.csv into DataFrame.
# 1056.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1056.csv into DataFrame.
# 1057.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1057.csv into DataFrame.
# 1058.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1058.csv into DataFrame.
# 1059.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1059.csv into DataFrame.
# 106.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/106.csv into DataFrame.
# 1060.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1060.csv into DataFrame.
# 1061.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1061.csv into DataFrame.
# 1062.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1062.csv into DataFrame.
# 1063.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1063.csv into DataFrame.
# 1064.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1064.csv into DataFrame.
# 1065.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1065.csv into DataFrame.
# 1066.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1066.csv into DataFrame.
# 1067.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1067.csv into DataFrame.
# 1068.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1068.csv into DataFrame.
# 1069.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1069.csv into DataFrame.
# 107.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/107.csv into DataFrame.
# 1070.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1070.csv into DataFrame.
# 1071.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1071.csv into DataFrame.
# 1072.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1072.csv into DataFrame.
# 1073.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1073.csv into DataFrame.
# 1074.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1074.csv into DataFrame.
# 1075.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1075.csv into DataFrame.
# 1076.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1076.csv into DataFrame.
# 1077.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1077.csv into DataFrame.
# 1078.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1078.csv into DataFrame.
# 1079.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1079.csv into DataFrame.
# 108.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/108.csv into DataFrame.
# 1080.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1080.csv into DataFrame.
# 1081.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1081.csv into DataFrame.
# 1082.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1082.csv into DataFrame.
# 1083.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1083.csv into DataFrame.
# 1084.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1084.csv into DataFrame.
# 1085.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1085.csv into DataFrame.
# 1086.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1086.csv into DataFrame.
# 1087.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1087.csv into DataFrame.
# 1088.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1088.csv into DataFrame.
# 1089.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1089.csv into DataFrame.
# 109.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/109.csv into DataFrame.
# 1090.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1090.csv into DataFrame.
# 1091.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1091.csv into DataFrame.
# 1092.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1092.csv into DataFrame.
# 1093.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1093.csv into DataFrame.
# 1094.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1094.csv into DataFrame.
# 1095.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1095.csv into DataFrame.
# 1096.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1096.csv into DataFrame.
# 1097.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1097.csv into DataFrame.
# 1098.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1098.csv into DataFrame.
# 1099.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1099.csv into DataFrame.
# 11.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/11.csv into DataFrame.
# 110.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/110.csv into DataFrame.
# 1100.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1100.csv into DataFrame.
# 1101.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1101.csv into DataFrame.
# 1102.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1102.csv into DataFrame.
# 1103.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1103.csv into DataFrame.
# 1104.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1104.csv into DataFrame.
# 1105.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1105.csv into DataFrame.
# 1106.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1106.csv into DataFrame.
# 1107.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1107.csv into DataFrame.
# 1108.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1108.csv into DataFrame.
# 1109.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1109.csv into DataFrame.
# 111.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/111.csv into DataFrame.
# 1110.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1110.csv into DataFrame.
# 1111.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1111.csv into DataFrame.
# 1112.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1112.csv into DataFrame.
# 1113.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1113.csv into DataFrame.
# 1114.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1114.csv into DataFrame.
# 1115.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1115.csv into DataFrame.
# 1116.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1116.csv into DataFrame.
# 1117.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1117.csv into DataFrame.
# 1118.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1118.csv into DataFrame.
# 1119.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1119.csv into DataFrame.
# 112.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/112.csv into DataFrame.
# 1120.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1120.csv into DataFrame.
# 1121.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1121.csv into DataFrame.
# 1122.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1122.csv into DataFrame.
# 1123.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1123.csv into DataFrame.
# 1124.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1124.csv into DataFrame.
# 1125.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1125.csv into DataFrame.
# 1126.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1126.csv into DataFrame.
# 1127.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1127.csv into DataFrame.
# 1128.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1128.csv into DataFrame.
# 1129.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1129.csv into DataFrame.
# 113.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/113.csv into DataFrame.
# 1130.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1130.csv into DataFrame.
# 1131.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1131.csv into DataFrame.
# 1132.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1132.csv into DataFrame.
# 1133.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1133.csv into DataFrame.
# 1134.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1134.csv into DataFrame.
# 1135.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1135.csv into DataFrame.
# 1136.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1136.csv into DataFrame.
# 1137.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1137.csv into DataFrame.
# 1138.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1138.csv into DataFrame.
# 1139.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1139.csv into DataFrame.
# 114.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/114.csv into DataFrame.
# 1140.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1140.csv into DataFrame.
# 1141.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1141.csv into DataFrame.
# 1142.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1142.csv into DataFrame.
# 1143.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1143.csv into DataFrame.
# 1144.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1144.csv into DataFrame.
# 1145.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1145.csv into DataFrame.
# 1146.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1146.csv into DataFrame.
# 1147.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1147.csv into DataFrame.
# 1148.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1148.csv into DataFrame.
# 1149.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1149.csv into DataFrame.
# 115.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/115.csv into DataFrame.
# 1150.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1150.csv into DataFrame.
# 1151.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1151.csv into DataFrame.
# 1152.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1152.csv into DataFrame.
# 1153.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1153.csv into DataFrame.
# 1154.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1154.csv into DataFrame.
# 1155.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1155.csv into DataFrame.
# 1156.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1156.csv into DataFrame.
# 1157.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1157.csv into DataFrame.
# 1158.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1158.csv into DataFrame.
# 1159.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1159.csv into DataFrame.
# 116.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/116.csv into DataFrame.
# 1160.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1160.csv into DataFrame.
# 1161.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1161.csv into DataFrame.
# 1162.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1162.csv into DataFrame.
# 1163.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1163.csv into DataFrame.
# 1164.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1164.csv into DataFrame.
# 1165.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1165.csv into DataFrame.
# 1166.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1166.csv into DataFrame.
# 1167.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1167.csv into DataFrame.
# 1168.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1168.csv into DataFrame.
# 1169.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1169.csv into DataFrame.
# 117.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/117.csv into DataFrame.
# 1170.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1170.csv into DataFrame.
# 1171.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1171.csv into DataFrame.
# 1172.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1172.csv into DataFrame.
# 1173.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1173.csv into DataFrame.
# 1174.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1174.csv into DataFrame.
# 1175.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1175.csv into DataFrame.
# 1176.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1176.csv into DataFrame.
# 1177.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1177.csv into DataFrame.
# 1178.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1178.csv into DataFrame.
# 1179.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1179.csv into DataFrame.
# 118.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/118.csv into DataFrame.
# 1180.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1180.csv into DataFrame.
# 1181.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1181.csv into DataFrame.
# 1182.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1182.csv into DataFrame.
# 1183.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1183.csv into DataFrame.
# 1184.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1184.csv into DataFrame.
# 1185.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1185.csv into DataFrame.
# 1186.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1186.csv into DataFrame.
# 1187.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1187.csv into DataFrame.
# 1188.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1188.csv into DataFrame.
# 1189.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1189.csv into DataFrame.
# 119.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/119.csv into DataFrame.
# 1190.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1190.csv into DataFrame.
# 1191.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1191.csv into DataFrame.
# 1192.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1192.csv into DataFrame.
# 1193.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1193.csv into DataFrame.
# 1194.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1194.csv into DataFrame.
# 1195.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1195.csv into DataFrame.
# 1196.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1196.csv into DataFrame.
# 1197.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1197.csv into DataFrame.
# 1198.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1198.csv into DataFrame.
# 1199.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1199.csv into DataFrame.
# 12.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/12.csv into DataFrame.
# 120.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/120.csv into DataFrame.
# 1200.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1200.csv into DataFrame.
# 1201.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1201.csv into DataFrame.
# 1202.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1202.csv into DataFrame.
# 1203.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1203.csv into DataFrame.
# 1204.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1204.csv into DataFrame.
# 1205.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1205.csv into DataFrame.
# 1206.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1206.csv into DataFrame.
# 1207.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1207.csv into DataFrame.
# 1208.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1208.csv into DataFrame.
# 1209.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1209.csv into DataFrame.
# 121.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/121.csv into DataFrame.
# 1210.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1210.csv into DataFrame.
# 1211.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1211.csv into DataFrame.
# 1212.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1212.csv into DataFrame.
# 1213.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1213.csv into DataFrame.
# 1214.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1214.csv into DataFrame.
# 1215.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1215.csv into DataFrame.
# 1216.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1216.csv into DataFrame.
# 1217.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1217.csv into DataFrame.
# 1218.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1218.csv into DataFrame.
# 1219.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1219.csv into DataFrame.
# 122.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/122.csv into DataFrame.
# 1220.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1220.csv into DataFrame.
# 1221.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1221.csv into DataFrame.
# 1222.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1222.csv into DataFrame.
# 1223.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1223.csv into DataFrame.
# 1224.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1224.csv into DataFrame.
# 1225.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1225.csv into DataFrame.
# 1226.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1226.csv into DataFrame.
# 1227.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1227.csv into DataFrame.
# 1228.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1228.csv into DataFrame.
# 1229.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1229.csv into DataFrame.
# 123.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/123.csv into DataFrame.
# 1230.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1230.csv into DataFrame.
# 1231.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1231.csv into DataFrame.
# 1232.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1232.csv into DataFrame.
# 1233.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1233.csv into DataFrame.
# 1234.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1234.csv into DataFrame.
# 1235.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1235.csv into DataFrame.
# 1236.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1236.csv into DataFrame.
# 1237.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1237.csv into DataFrame.
# 1238.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1238.csv into DataFrame.
# 1239.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1239.csv into DataFrame.
# 124.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/124.csv into DataFrame.
# 1240.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1240.csv into DataFrame.
# 1241.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1241.csv into DataFrame.
# 1242.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1242.csv into DataFrame.
# 1243.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1243.csv into DataFrame.
# 1244.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1244.csv into DataFrame.
# 1245.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1245.csv into DataFrame.
# 1246.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1246.csv into DataFrame.
# 1247.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1247.csv into DataFrame.
# 1248.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1248.csv into DataFrame.
# 1249.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1249.csv into DataFrame.
# 125.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/125.csv into DataFrame.
# 1250.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1250.csv into DataFrame.
# 1251.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1251.csv into DataFrame.
# 1252.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1252.csv into DataFrame.
# 1253.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1253.csv into DataFrame.
# 1254.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1254.csv into DataFrame.
# 1255.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1255.csv into DataFrame.
# 1256.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1256.csv into DataFrame.
# 1257.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1257.csv into DataFrame.
# 1258.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1258.csv into DataFrame.
# 1259.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1259.csv into DataFrame.
# 126.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/126.csv into DataFrame.
# 1260.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1260.csv into DataFrame.
# 1261.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1261.csv into DataFrame.
# 1262.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1262.csv into DataFrame.
# 1263.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1263.csv into DataFrame.
# 1264.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1264.csv into DataFrame.
# 1265.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1265.csv into DataFrame.
# 1266.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1266.csv into DataFrame.
# 1267.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1267.csv into DataFrame.
# 1268.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1268.csv into DataFrame.
# 1269.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1269.csv into DataFrame.
# 127.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/127.csv into DataFrame.
# 1270.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1270.csv into DataFrame.
# 1271.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1271.csv into DataFrame.
# 1272.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1272.csv into DataFrame.
# 1273.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1273.csv into DataFrame.
# 1274.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1274.csv into DataFrame.
# 1275.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1275.csv into DataFrame.
# 1276.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1276.csv into DataFrame.
# 1277.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1277.csv into DataFrame.
# 1278.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1278.csv into DataFrame.
# 1279.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1279.csv into DataFrame.
# 128.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/128.csv into DataFrame.
# 1280.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1280.csv into DataFrame.
# 1281.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1281.csv into DataFrame.
# 1282.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1282.csv into DataFrame.
# 1283.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1283.csv into DataFrame.
# 1284.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1284.csv into DataFrame.
# 1285.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1285.csv into DataFrame.
# 1286.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1286.csv into DataFrame.
# 1287.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1287.csv into DataFrame.
# 1288.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1288.csv into DataFrame.
# 1289.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1289.csv into DataFrame.
# 129.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/129.csv into DataFrame.
# 1290.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1290.csv into DataFrame.
# 1291.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1291.csv into DataFrame.
# 1292.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1292.csv into DataFrame.
# 1293.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1293.csv into DataFrame.
# 1294.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1294.csv into DataFrame.
# 1295.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1295.csv into DataFrame.
# 1296.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1296.csv into DataFrame.
# 1297.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1297.csv into DataFrame.
# 1298.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1298.csv into DataFrame.
# 1299.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1299.csv into DataFrame.
# 13.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/13.csv into DataFrame.
# 130.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/130.csv into DataFrame.
# 1300.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1300.csv into DataFrame.
# 1301.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1301.csv into DataFrame.
# 1302.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1302.csv into DataFrame.
# 1303.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1303.csv into DataFrame.
# 1304.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1304.csv into DataFrame.
# 1305.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1305.csv into DataFrame.
# 1306.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1306.csv into DataFrame.
# 1307.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1307.csv into DataFrame.
# 1308.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1308.csv into DataFrame.
# 1309.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1309.csv into DataFrame.
# 131.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/131.csv into DataFrame.
# 1310.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1310.csv into DataFrame.
# 1311.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1311.csv into DataFrame.
# 1312.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1312.csv into DataFrame.
# 1313.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1313.csv into DataFrame.
# 1314.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1314.csv into DataFrame.
# 1315.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1315.csv into DataFrame.
# 1316.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1316.csv into DataFrame.
# 1317.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1317.csv into DataFrame.
# 1318.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1318.csv into DataFrame.
# 1319.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1319.csv into DataFrame.
# 132.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/132.csv into DataFrame.
# 1320.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1320.csv into DataFrame.
# 1321.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1321.csv into DataFrame.
# 1322.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1322.csv into DataFrame.
# 1323.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1323.csv into DataFrame.
# 1324.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1324.csv into DataFrame.
# 1325.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1325.csv into DataFrame.
# 1326.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1326.csv into DataFrame.
# 1327.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1327.csv into DataFrame.
# 1328.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1328.csv into DataFrame.
# 1329.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1329.csv into DataFrame.
# 133.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/133.csv into DataFrame.
# 1330.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1330.csv into DataFrame.
# 1331.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1331.csv into DataFrame.
# 1332.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1332.csv into DataFrame.
# 1333.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1333.csv into DataFrame.
# 1334.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1334.csv into DataFrame.
# 1335.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1335.csv into DataFrame.
# 1336.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1336.csv into DataFrame.
# 1337.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1337.csv into DataFrame.
# 1338.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1338.csv into DataFrame.
# 1339.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1339.csv into DataFrame.
# 134.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/134.csv into DataFrame.
# 1340.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1340.csv into DataFrame.
# 1341.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1341.csv into DataFrame.
# 1342.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1342.csv into DataFrame.
# 1343.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1343.csv into DataFrame.
# 1344.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1344.csv into DataFrame.
# 1345.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1345.csv into DataFrame.
# 1346.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1346.csv into DataFrame.
# 1347.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1347.csv into DataFrame.
# 1348.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1348.csv into DataFrame.
# 1349.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1349.csv into DataFrame.
# 135.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/135.csv into DataFrame.
# 1350.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1350.csv into DataFrame.
# 1351.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1351.csv into DataFrame.
# 1352.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1352.csv into DataFrame.
# 1353.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1353.csv into DataFrame.
# 1354.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1354.csv into DataFrame.
# 1355.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1355.csv into DataFrame.
# 1356.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1356.csv into DataFrame.
# 1357.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1357.csv into DataFrame.
# 1358.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1358.csv into DataFrame.
# 1359.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1359.csv into DataFrame.
# 136.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/136.csv into DataFrame.
# 1360.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1360.csv into DataFrame.
# 1361.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1361.csv into DataFrame.
# 1362.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1362.csv into DataFrame.
# 1363.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1363.csv into DataFrame.
# 1364.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1364.csv into DataFrame.
# 1365.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1365.csv into DataFrame.
# 1366.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1366.csv into DataFrame.
# 1367.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1367.csv into DataFrame.
# 1368.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1368.csv into DataFrame.
# 1369.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1369.csv into DataFrame.
# 137.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/137.csv into DataFrame.
# 1370.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1370.csv into DataFrame.
# 1371.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1371.csv into DataFrame.
# 1372.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1372.csv into DataFrame.
# 1373.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1373.csv into DataFrame.
# 1374.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1374.csv into DataFrame.
# 1375.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1375.csv into DataFrame.
# 1376.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1376.csv into DataFrame.
# 1377.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1377.csv into DataFrame.
# 1378.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1378.csv into DataFrame.
# 1379.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1379.csv into DataFrame.
# 138.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/138.csv into DataFrame.
# 1380.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1380.csv into DataFrame.
# 1381.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1381.csv into DataFrame.
# 1382.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1382.csv into DataFrame.
# 1383.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1383.csv into DataFrame.
# 1384.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1384.csv into DataFrame.
# 1385.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1385.csv into DataFrame.
# 1386.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1386.csv into DataFrame.
# 1387.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1387.csv into DataFrame.
# 1388.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1388.csv into DataFrame.
# 1389.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1389.csv into DataFrame.
# 139.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/139.csv into DataFrame.
# 1390.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1390.csv into DataFrame.
# 1391.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1391.csv into DataFrame.
# 1392.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1392.csv into DataFrame.
# 1393.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1393.csv into DataFrame.
# 1394.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1394.csv into DataFrame.
# 1395.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1395.csv into DataFrame.
# 1396.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1396.csv into DataFrame.
# 1397.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1397.csv into DataFrame.
# 1398.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1398.csv into DataFrame.
# 1399.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1399.csv into DataFrame.
# 14.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/14.csv into DataFrame.
# 140.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/140.csv into DataFrame.
# 1400.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1400.csv into DataFrame.
# 1401.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1401.csv into DataFrame.
# 1402.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1402.csv into DataFrame.
# 1403.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1403.csv into DataFrame.
# 1404.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1404.csv into DataFrame.
# 1405.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1405.csv into DataFrame.
# 1406.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1406.csv into DataFrame.
# 1407.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1407.csv into DataFrame.
# 1408.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1408.csv into DataFrame.
# 1409.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1409.csv into DataFrame.
# 141.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/141.csv into DataFrame.
# 1410.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1410.csv into DataFrame.
# 1411.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1411.csv into DataFrame.
# 1412.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1412.csv into DataFrame.
# 1413.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1413.csv into DataFrame.
# 1414.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1414.csv into DataFrame.
# 1415.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1415.csv into DataFrame.
# 1416.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1416.csv into DataFrame.
# 1417.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1417.csv into DataFrame.
# 1418.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1418.csv into DataFrame.
# 1419.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1419.csv into DataFrame.
# 142.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/142.csv into DataFrame.
# 1420.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1420.csv into DataFrame.
# 1421.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1421.csv into DataFrame.
# 1422.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1422.csv into DataFrame.
# 1423.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1423.csv into DataFrame.
# 1424.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1424.csv into DataFrame.
# 1425.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1425.csv into DataFrame.
# 1426.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1426.csv into DataFrame.
# 1427.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1427.csv into DataFrame.
# 1428.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1428.csv into DataFrame.
# 1429.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1429.csv into DataFrame.
# 143.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/143.csv into DataFrame.
# 1430.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1430.csv into DataFrame.
# 1431.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1431.csv into DataFrame.
# 1432.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1432.csv into DataFrame.
# 1433.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1433.csv into DataFrame.
# 1434.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1434.csv into DataFrame.
# 1435.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1435.csv into DataFrame.
# 1436.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1436.csv into DataFrame.
# 1437.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1437.csv into DataFrame.
# 1438.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1438.csv into DataFrame.
# 1439.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1439.csv into DataFrame.
# 144.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/144.csv into DataFrame.
# 1440.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1440.csv into DataFrame.
# 1441.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1441.csv into DataFrame.
# 1442.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1442.csv into DataFrame.
# 1443.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1443.csv into DataFrame.
# 1444.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1444.csv into DataFrame.
# 1445.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1445.csv into DataFrame.
# 1446.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1446.csv into DataFrame.
# 1447.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1447.csv into DataFrame.
# 1448.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1448.csv into DataFrame.
# 1449.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1449.csv into DataFrame.
# 145.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/145.csv into DataFrame.
# 1450.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1450.csv into DataFrame.
# 1451.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1451.csv into DataFrame.
# 1452.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1452.csv into DataFrame.
# 1453.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1453.csv into DataFrame.
# 1454.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1454.csv into DataFrame.
# 1455.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1455.csv into DataFrame.
# 1456.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1456.csv into DataFrame.
# 1457.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1457.csv into DataFrame.
# 1458.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1458.csv into DataFrame.
# 1459.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1459.csv into DataFrame.
# 146.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/146.csv into DataFrame.
# 1460.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1460.csv into DataFrame.
# 1461.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1461.csv into DataFrame.
# 1462.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1462.csv into DataFrame.
# 1463.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1463.csv into DataFrame.
# 1464.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1464.csv into DataFrame.
# 1465.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1465.csv into DataFrame.
# 1466.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1466.csv into DataFrame.
# 1467.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1467.csv into DataFrame.
# 1468.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1468.csv into DataFrame.
# 1469.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1469.csv into DataFrame.
# 147.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/147.csv into DataFrame.
# 1470.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1470.csv into DataFrame.
# 1471.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1471.csv into DataFrame.
# 1472.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1472.csv into DataFrame.
# 1473.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1473.csv into DataFrame.
# 1474.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1474.csv into DataFrame.
# 1475.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1475.csv into DataFrame.
# 1476.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1476.csv into DataFrame.
# 1477.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1477.csv into DataFrame.
# 1478.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1478.csv into DataFrame.
# 1479.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1479.csv into DataFrame.
# 148.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/148.csv into DataFrame.
# 1480.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1480.csv into DataFrame.
# 1481.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1481.csv into DataFrame.
# 1482.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1482.csv into DataFrame.
# 1483.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1483.csv into DataFrame.
# 1484.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1484.csv into DataFrame.
# 1485.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1485.csv into DataFrame.
# 1486.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1486.csv into DataFrame.
# 1487.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1487.csv into DataFrame.
# 1488.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1488.csv into DataFrame.
# 1489.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1489.csv into DataFrame.
# 149.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/149.csv into DataFrame.
# 1490.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1490.csv into DataFrame.
# 1491.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1491.csv into DataFrame.
# 1492.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1492.csv into DataFrame.
# 1493.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1493.csv into DataFrame.
# 1494.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1494.csv into DataFrame.
# 1495.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1495.csv into DataFrame.
# 1496.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1496.csv into DataFrame.
# 1497.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1497.csv into DataFrame.
# 1498.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1498.csv into DataFrame.
# 1499.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1499.csv into DataFrame.
# 15.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/15.csv into DataFrame.
# 150.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/150.csv into DataFrame.
# 1500.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1500.csv into DataFrame.
# 1501.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1501.csv into DataFrame.
# 1502.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1502.csv into DataFrame.
# 1503.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1503.csv into DataFrame.
# 1504.csv: 0.00B [00:00, ?B/s]
# ...
# Loaded Bangla_fin_news_articles/161.csv into DataFrame.
# 1610.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1610.csv into DataFrame.
# 1611.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1611.csv into DataFrame.
# 1612.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1612.csv into DataFrame.
# 1613.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1613.csv into DataFrame.
# 1614.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1614.csv into DataFrame.
# 1615.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1615.csv into DataFrame.
# 1616.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1616.csv into DataFrame.
# 1617.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1617.csv into DataFrame.
# 1618.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1618.csv into DataFrame.
# 1619.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1619.csv into DataFrame.
# 162.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/162.csv into DataFrame.
# 1620.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1620.csv into DataFrame.
# 1621.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1621.csv into DataFrame.
# 1622.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1622.csv into DataFrame.
# 1623.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1623.csv into DataFrame.
# 1624.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1624.csv into DataFrame.
# 1625.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1625.csv into DataFrame.
# 1626.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1626.csv into DataFrame.
# 1627.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1627.csv into DataFrame.
# 1628.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1628.csv into DataFrame.
# 1629.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1629.csv into DataFrame.
# 163.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/163.csv into DataFrame.
# 1630.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1630.csv into DataFrame.
# 1631.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1631.csv into DataFrame.
# 1632.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1632.csv into DataFrame.
# 1633.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1633.csv into DataFrame.
# 1634.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1634.csv into DataFrame.
# 1635.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1635.csv into DataFrame.
# 1636.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1636.csv into DataFrame.
# 1637.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1637.csv into DataFrame.
# 1638.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1638.csv into DataFrame.
# 1639.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1639.csv into DataFrame.
# 164.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/164.csv into DataFrame.
# 1640.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1640.csv into DataFrame.
# 1641.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1641.csv into DataFrame.
# 1642.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1642.csv into DataFrame.
# 1643.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1643.csv into DataFrame.
# 1644.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1644.csv into DataFrame.
# 1645.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1645.csv into DataFrame.
# 1646.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1646.csv into DataFrame.
# 1647.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1647.csv into DataFrame.
# 1648.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1648.csv into DataFrame.
# 1649.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1649.csv into DataFrame.
# 165.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/165.csv into DataFrame.
# 1650.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1650.csv into DataFrame.
# 1651.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1651.csv into DataFrame.
# 1652.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1652.csv into DataFrame.
# 1653.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1653.csv into DataFrame.
# 1654.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1654.csv into DataFrame.
# 1655.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1655.csv into DataFrame.
# 1656.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1656.csv into DataFrame.
# 1657.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1657.csv into DataFrame.
# 1658.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1658.csv into DataFrame.
# 1659.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1659.csv into DataFrame.
# 166.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/166.csv into DataFrame.
# 1660.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1660.csv into DataFrame.
# 1661.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1661.csv into DataFrame.
# 1662.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1662.csv into DataFrame.
# 1663.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1663.csv into DataFrame.
# 1664.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1664.csv into DataFrame.
# 1665.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1665.csv into DataFrame.
# 1666.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1666.csv into DataFrame.
# 1667.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1667.csv into DataFrame.
# 1668.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1668.csv into DataFrame.
# 1669.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1669.csv into DataFrame.
# 167.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/167.csv into DataFrame.
# 1670.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1670.csv into DataFrame.
# 1671.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1671.csv into DataFrame.
# 1672.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1672.csv into DataFrame.
# 1673.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1673.csv into DataFrame.
# 1674.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1674.csv into DataFrame.
# 1675.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1675.csv into DataFrame.
# 1676.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1676.csv into DataFrame.
# 1677.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1677.csv into DataFrame.
# 1678.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1678.csv into DataFrame.
# 1679.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1679.csv into DataFrame.
# 168.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/168.csv into DataFrame.
# 1680.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1680.csv into DataFrame.
# 1681.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1681.csv into DataFrame.
# 1682.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1682.csv into DataFrame.
# 1683.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1683.csv into DataFrame.
# 1684.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1684.csv into DataFrame.
# 1685.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1685.csv into DataFrame.
# 1686.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1686.csv into DataFrame.
# 1687.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1687.csv into DataFrame.
# 1688.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1688.csv into DataFrame.
# 1689.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1689.csv into DataFrame.
# 169.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/169.csv into DataFrame.
# 1690.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1690.csv into DataFrame.
# 1691.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1691.csv into DataFrame.
# 1692.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1692.csv into DataFrame.
# 1693.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1693.csv into DataFrame.
# 1694.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1694.csv into DataFrame.
# 1695.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1695.csv into DataFrame.
# 1696.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1696.csv into DataFrame.
# 1697.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1697.csv into DataFrame.
# 1698.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1698.csv into DataFrame.
# 1699.csv: 0.00B [00:00, ?B/s]
# Loaded Bangla_fin_news_articles/1699.csv into DataFrame.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2329186848.py in <cell line: 0>()
#       2 dfs = []
#       3 for file in csv_files:
# ----> 4     local_path = hf_hub_download(
#       5         repo_id=repo_id,
#       6         filename=file,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1005         )
#    1006     else:
# -> 1007         return _hf_hub_download_to_cache_dir(
#    1008             # Destination
#    1009             cache_dir=cache_dir,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1166
#    1167     with WeakFileLock(lock_path):
# -> 1168         _download_to_tmp_and_move(
#    1169             incomplete_path=Path(blob_path + ".incomplete"),
#    1170             destination_path=Path(blob_path),
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1733                 )
#    1734
# -> 1735             http_get(
#    1736                 url_to_download,
#    1737                 f,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     421             )
#     422
# --> 423     r = _request_wrapper(
#     424         method="GET", url=url, stream=True, proxies=proxies, headers=headers, timeout=constants.HF_HUB_DOWNLOAD_TIMEOUT
#     425     )
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     304
#     305     # Perform request and return if status_code is not in the retry list.
# --> 306     response = http_backoff(method=method, url=url, **params)
#     307     hf_raise_for_status(response)
#     308     return response
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     304
#     305             # Perform request and return if status_code is not in the retry list.
# --> 306             response = session.request(method=method, url=url, **kwargs)
#     307             if response.status_code not in retry_on_status_codes:
#     308                 return response
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in send(self, request, *args, **kwargs)
#      93             logger.debug(f"Send: {_curlify(request)}")
#      94         try:
# ---> 95             return super().send(request, *args, **kwargs)
#      96         except requests.RequestException as e:
#      97             request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1428         try:
#    1429             try:
# -> 1430                 response.begin()
#    1431             except ConnectionError:
#    1432                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     329         # read until we get a non-100 response
#     330         while True:
# --> 331             version, status, reason = self._read_status()
#     332             if status != CONTINUE:
#     333                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     290
#     291     def _read_status(self):
# --> 292         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293         if len(line) > _MAXLINE:
#     294             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
full_df = pd.read_csv("/content/combined_full_df.csv")
full_df.head()
# Out:
#   Serial                                              Title        Date  \
# 0   7025  অর্থ মন্ত্রণালয়ের কর্মকর্তাসহ ৭ জনের বিরুদ্ধে ...  2014-11-16
# 1   7026               শেয়ারবাজারে সূচক কমলেও বেড়েছে লেনদেন  2014-11-16
# 2   7027         কোহিনুর ঢাকা ডায়িং ও ওরিয়নের লভ্যাংশ ঘোষণা  2014-11-15
# 3   7028         বাংলাদেশে জ্বালানিতে বিনিয়োগের শ্রেষ্ঠ সময়  2014-11-15
# 4   7029                         কমছে না খেলাপি ঋণের পরিমাণ  2014-11-15
#
#              Author                                               News
# 0  ইত্তেফাক রিপোর্ট  ইলেকট্রনিক ফান্ড ট্রান্সফার ইএফটি জালিয়াতির মা...
# 1  ইত্তেফাক রিপোর্ট  শেয়ারবাজারে রবিবার সূচক কমলেও বেড়েছে লেনদেনের ...
# 2  ইত্তেফাক রিপোর্ট  শেয়ারবাজারে তালিকাভুক্ত কোহিনুর কেমিক্যাল ঢাকা...
# 3  ইত্তেফাক রিপোর্ট  বাংলাদেশ ভারতের কাছ থেকে প্রাকৃতিক গ্যাস সমৃদ্...
# 4  ইত্তেফাক রিপোর্ট  দেশের রাজনৈতিক পরিস্থিতি স্বাভাবিক হলেও ব্যবসা...

# %%
# Tokenization Foundations
text = "আমি বাংলায় কথা বলি"
tokens = text.split()  # ['আমি', 'বাংলায়', 'কথা', 'বলি']
tokens
# Out:
# ['আমি', 'বাংলায়', 'কথা', 'বলি']

# %%
from transformers import AutoTokenizer

TOKENIZER = "csebuetnlp/banglat5"
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER)

print(f"Vocabulary size: {tokenizer.vocab_size}")
print(f"Model max length: {tokenizer.model_max_length}")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Vocabulary size: 32100
# Model max length: 512

# %%
# Example tokenization
text = "বাংলাদেশ একটি সুন্দর দেশ"
tokens = tokenizer.tokenize(text)
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print(f"Original text: {text}")
print(f"Tokens: {tokens}")
print(f"Token IDs: {token_ids}")

# Reverse process
decoded = tokenizer.decode(token_ids)
print(f"Decoded: {decoded}")
# Out:
# Original text: বাংলাদেশ একটি সুন্দর দেশ
# Tokens: ['▁বাংলাদেশ', '▁একটি', '▁সুন্দর', '▁দেশ']
# Token IDs: [249, 60, 433, 415]
# Decoded: বাংলাদেশ একটি সুন্দর দেশ

# %%
# In our case, we use 'News' column
text_col = 'News'
assert text_col in full_df.columns, f"Column '{text_col}' not found!"
print(f"Using column '{text_col}' as text.")

# Rename for standardization
df_clean = full_df[[text_col]].rename(columns={text_col: "text"})
df_clean.columns
# Out:
# Using column 'News' as text.
# Index(['text'], dtype='object')

# %%
TEST_SPLIT = 0.05  # 5% for validation

# Reasoning:
# - Large dataset (7,695 files) = enough validation data
# - More training data = better model performance
# - 5% still provides reliable evaluation metrics

# %%
from datasets import Dataset, DatasetDict

# Convert to HuggingFace Dataset
ds_full = Dataset.from_pandas(df_clean)

# Shuffle for randomness
ds_full = ds_full.shuffle(seed=42)

# Split the dataset
splits = ds_full.train_test_split(test_size=TEST_SPLIT, seed=42)
ds = DatasetDict({
    "train": splits["train"],
    "validation": splits["test"]
})

print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 7343
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 387
#     })
# })

# %%
def tokenize_function(batch):
    texts = [str(x) if x is not None else "" for x in batch["text"]]

    out = tokenizer(
        texts,
        add_special_tokens=False,    # Don't add [CLS], [SEP] tokens
        truncation=True,             # Cut text if too long
        max_length=512               # Maximum sequence length
    )

    return {
        "ids": out["input_ids"],
        "len": [len(x) for x in out["input_ids"]],
    }

# %%
# Apply tokenization to entire dataset
tokenized_ds = ds.map(
    tokenize_function,
    batched=True,                    # Process in batches for efficiency
    num_proc=4,                      # Use 4 CPU cores
    remove_columns=[],               # Originally we will use - "remove_columns=["text"], " to Remove original text column
    desc="Tokenizing",               # Progress bar description
)

print(tokenized_ds)
# Out:
# Tokenizing (num_proc=4):   0%|          | 0/7343 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1395: FutureWarning: promote has been superseded by promote_options='default'.
#   block_group = [InMemoryTable(cls._concat_blocks(list(block_group), axis=axis))]
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Tokenizing (num_proc=4):   0%|          | 0/387 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'ids', 'len'],
#         num_rows: 7343
#     })
#     validation: Dataset({
#         features: ['text', 'ids', 'len'],
#         num_rows: 387
#     })
# })
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1395: FutureWarning: promote has been superseded by promote_options='default'.
#   block_group = [InMemoryTable(cls._concat_blocks(list(block_group), axis=axis))]
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
for i in range(1):
    original_text = ds["train"][i]["text"]
    input_ids = tokenizer.encode(original_text)
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    decoded = tokenizer.decode(input_ids)

    print(f"\n=== Sample {i} ===")
    print(f"Original text: {original_text}")
    print(f"Tokens: {tokens}")
    print(f"Token IDs: {input_ids}")
    print(f"Decoded: {decoded}")
# Out:
# === Sample 0 ===
# Original text: নারী ও শিশুদের স্বাস্থ্য সুরক্ষায় স্টেসেফ ব্র্যান্ডের স্যানিটারি ন্যাপকিন ও কিডস্টার ব্র্যান্ডের বেবি ডায়পার উৎপাদন শুরু করেছে প্রাণ গ্রুপের সহযোগী প্রতিষ্ঠান এডভান্সড পারসোনাল কেয়ার লিমিটেডএপিসিএল।  বুধবার বিকেলে গাজীপুরের কালীগঞ্জে আরএফএল ইন্ডাস্ট্রিয়াল পার্কে এর উদ্বোধন করেন মহিলা ও শিশু বিষয়ক প্রতিমন্ত্রী মেহের আফরোজ চুমকি।  অনুষ্ঠানে মেহের আফরোজ চুমকি স্থানীয় পর্যায়ে কর্মসংস্থান সৃষ্টিতে প্রাণআরএফএল গ্রুপের ভূমিকার কথা উল্লেখ করেন। পাশাপাশি কারখানায় নারীদের ব্যাপক কর্মসংস্থানে তিনি সন্তোষ প্রকাশ করেন।  প্রাণ এর ব্যবস্থাপনা পরিচালক ইলিয়াছ মৃধা বলেন বর্তমানে মানুষ স্বাস্থ্য বিষয়ে অনেক সচেতন। সেজন্যে পার্সোনাল হাইজিন প্রোডাক্টের চাহিদা দিন দিন বাড়ছে। শিগগিরই এপিসিএল এর উন্নতমানের স্টেসেফ ব্র্যান্ডের স্যানিটারি ন্যাপকিন ও কিডস্টার ব্র্যান্ডের বেবি ডায়পার বাজারে পাওয়া যাবে। এই পণ্যগুলি ক্রেতাদের কাছে জনপ্রিয়তা পাবে।  অনুষ্ঠানে প্রাণআরএফএল গ্রুপের চেয়ারম্যান ও সিইও আহসান খান চেীধুরী আরএফএল এর ব্যবস্থাপনা পরিচালক আর এন পাল এপিসিএলএর এক্সিকিউটিভ ডিরেক্টর মোহাম্মদ মনিরুজ্জামান আরএফএল ইন্ডাস্ট্রিয়াল পার্কের সিনিয়র জেনারেল ম্যানেজার কমান্ডার অব. শামসুল আলম মিয়া ও এপিসিএলএর হেড অব মার্কেটিং রুহুল এফ তালুকদার সুমনসহ কোম্পানির ঊর্ধ্বতন কর্মকর্তারা উপস্থিত ছিলেন।  ইত্তেফাকইউবি
# Tokens: ['▁নারী', '▁ও', '▁শিশুদের', '▁স্বাস্থ্য', '▁সুরক্ষা', 'য়', '▁স্টে', 'সেফ', '▁ব্র্যান্ডের', '▁স্যানিটারি', '▁ন্যাপকিন', '▁ও', '▁কি', 'ড', 'স্টার', '▁ব্র্যান্ডের', '▁বেবি', '▁ডায়', 'পার', '▁উৎপাদন', '▁শুরু', '▁করেছে', '▁প্রাণ', '▁গ্রুপের', '▁সহযোগী', '▁প্রতিষ্ঠান', '▁এড', 'ভা', 'ন্স', 'ড', '▁পারসোনাল', '▁কেয়ার', '▁লিমিটেড', 'এপি', 'সিএল', '।', '▁বুধবার', '▁বিকেলে', '▁গাজীপুরের', '▁কালীগঞ্জ', 'ে', '▁আর', 'এফএল', '▁ইন্ডাস্ট্রিয়াল', '▁পার্কে', '▁এর', '▁উদ্বোধন', '▁করেন', '▁মহিলা', '▁ও', '▁শিশু', '▁বিষয়ক', '▁প্রতিমন্ত্রী', '▁মেহের', '▁আফরোজ', '▁চুমকি', '।', '▁অনুষ্ঠানে', '▁মেহের', '▁আফরোজ', '▁চুমকি', '▁স্থানীয়', '▁পর্যায়ে', '▁কর্মসংস্থান', '▁সৃষ্টি', 'তে', '▁প্রাণ', 'আর', 'এফএল', '▁গ্রুপের', '▁ভূমিকার', '▁কথা', '▁উল্লেখ', '▁করেন', '।', '▁পাশাপাশি', '▁কারখানায়', '▁নারীদের', '▁ব্যাপক', '▁কর্মসংস্থান', 'ে', '▁তিনি', '▁সন্তোষ', '▁প্রকাশ', '▁করেন', '।', '▁প্রাণ', '▁এর', '▁ব্যবস্থাপনা', '▁পরিচালক', '▁ই', 'লিয়া', 'ছ', '▁মৃধা', '▁বলেন', '▁বর্তমানে', '▁মানুষ', '▁স্বাস্থ্য', '▁বিষয়ে', '▁অনেক', '▁সচেতন', '।', '▁সেজন্য', 'ে', '▁পার্স', 'ে', 'া', 'নাল', '▁হাই', 'জিন', '▁প্রোডাক্ট', 'ের', '▁চাহিদা', '▁দিন', '▁দিন', '▁বাড়ছে', '।', '▁শিগগিরই', '▁এপি', 'সিএল', '▁এর', '▁উন্নতমানের', '▁স্টে', 'সেফ', '▁ব্র্যান্ডের', '▁স্যানিটারি', '▁ন্যাপকিন', '▁ও', '▁কি', 'ড', 'স্টার', '▁ব্র্যান্ডের', '▁বেবি', '▁ডায়', 'পার', '▁বাজারে', '▁পাওয়া', '▁যাবে', '।', '▁এই', '▁পণ্য', 'গুলি', '▁ক্রেতাদের', '▁কাছে', '▁জনপ্রিয়তা', '▁পাবে', '।', '▁অনুষ্ঠানে', '▁প্রাণ', 'আর', 'এফএল', '▁গ্রুপের', '▁চেয়ারম্যান', '▁ও', '▁সিইও', '▁আহসান', '▁খান', '▁চে', 'ী', 'ধুর', 'ী', '▁আর', 'এফএল', '▁এর', '▁ব্যবস্থাপনা', '▁পরিচালক', '▁আর', '▁এন', '▁পাল', '▁এপি', 'সিএল', 'এর', '▁এক্সিকিউটিভ', '▁ডিরেক্টর', '▁মোহাম্মদ', '▁মনিরুজ্জামান', '▁আর', 'এফএল', '▁ইন্ডাস্ট্রিয়াল', '▁পার্কের', '▁সিনিয়র', '▁জেনারেল', '▁ম্যানেজার', '▁কমান্ডার', '▁অব', '.', '▁শামসুল', '▁আলম', '▁মিয়া', '▁ও', '▁এপি', 'সিএল', 'এর', '▁হেড', '▁অব', '▁মার্কেটিং', '▁রুহুল', '▁এফ', '▁তালুকদার', '▁সুমন', 'সহ', '▁কোম্পানির', '▁ঊর্ধ্বতন', '▁কর্মকর্তারা', '▁উপস্থিত', '▁ছিলেন', '।', '▁ইত্তেফাক', 'ইউ', 'বি', '</s>']
# Token IDs: [498, 11, 2629, 1007, 5781, 67, 8082, 19000, 14705, 31966, 30649, 11, 29, 495, 4270, 14705, 9345, 15216, 1795, 2419, 105, 168, 964, 4712, 3699, 1300, 5060, 1723, 3045, 495, 30858, 5724, 6002, 24176, 16583, 3, 1286, 1471, 12820, 20379, 10, 12, 28597, 31646, 6838, 61, 3113, 79, 1071, 11, 826, 4018, 5379, 9054, 25406, 21298, 3, 1148, 9054, 25406, 21298, 618, 1640, 9671, 652, 57, 964, 620, 28597, 4712, 19779, 39, 1098, 79, 3, 711, 7266, 2824, 2077, 9671, 10, 52, 12253, 428, 79, 3, 964, 61, 3392, 1093, 265, 3529, 654, 21955, 93, 1044, 155, 1007, 391, 76, 3099, 3, 6484, 10, 15212, 10, 95, 6259, 1824, 7383, 17190, 6, 2592, 98, 98, 2488, 3, 9110, 16848, 16583, 61, 30354, 8082, 19000, 14705, 31966, 30649, 11, 29, 495, 4270, 14705, 9345, 15216, 1795, 1265, 243, 154, 3, 14, 1916, 713, 13812, 81, 5952, 1126, 3, 1148, 964, 620, 28597, 4712, 1012, 11, 17856, 5037, 613, 2790, 149, 12048, 149, 12, 28597, 61, 3392, 1093, 12, 1995, 2269, 16848, 16583, 326, 27821, 7321, 1264, 17106, 12, 28597, 31646, 9287, 4265, 1918, 3802, 6224, 699, 26, 9748, 1408, 1682, 11, 16848, 16583, 326, 4057, 699, 11798, 9168, 4598, 7450, 3697, 255, 3118, 9607, 4060, 876, 203, 3, 22694, 3252, 262, 1]
# Decoded: নারী ও শিশুদের স্বাস্থ্য সুরক্ষায় স্টেসেফ ব্র্যান্ডের স্যানিটারি ন্যাপকিন ও কিডস্টার ব্র্যান্ডের বেবি ডায়পার উৎপাদন শুরু করেছে প্রাণ গ্রুপের সহযোগী প্রতিষ্ঠান এডভান্সড পারসোনাল কেয়ার লিমিটেডএপিসিএল। বুধবার বিকেলে গাজীপুরের কালীগঞ্জে আরএফএল ইন্ডাস্ট্রিয়াল পার্কে এর উদ্বোধন করেন মহিলা ও শিশু বিষয়ক প্রতিমন্ত্রী মেহের আফরোজ চুমকি। অনুষ্ঠানে মেহের আফরোজ চুমকি স্থানীয় পর্যায়ে কর্মসংস্থান সৃষ্টিতে প্রাণআরএফএল গ্রুপের ভূমিকার কথা উল্লেখ করেন। পাশাপাশি কারখানায় নারীদের ব্যাপক কর্মসংস্থানে তিনি সন্তোষ প্রকাশ করেন। প্রাণ এর ব্যবস্থাপনা পরিচালক ইলিয়াছ মৃধা বলেন বর্তমানে মানুষ স্বাস্থ্য বিষয়ে অনেক সচেতন। সেজন্যে পার্সোনাল হাইজিন প্রোডাক্টের চাহিদা দিন দিন বাড়ছে। শিগগিরই এপিসিএল এর উন্নতমানের স্টেসেফ ব্র্যান্ডের স্যানিটারি ন্যাপকিন ও কিডস্টার ব্র্যান্ডের বেবি ডায়পার বাজারে পাওয়া যাবে। এই পণ্যগুলি ক্রেতাদের কাছে জনপ্রিয়তা পাবে। অনুষ্ঠানে প্রাণআরএফএল গ্রুপের চেয়ারম্যান ও সিইও আহসান খান চেীধুরী আরএফএল এর ব্যবস্থাপনা পরিচালক আর এন পাল এপিসিএলএর এক্সিকিউটিভ ডিরেক্টর মোহাম্মদ মনিরুজ্জামান আরএফএল ইন্ডাস্ট্রিয়াল পার্কের সিনিয়র জেনারেল ম্যানেজার কমান্ডার অব. শামসুল আলম মিয়া ও এপিসিএলএর হেড অব মার্কেটিং রুহুল এফ তালুকদার সুমনসহ কোম্পানির ঊর্ধ্বতন কর্মকর্তারা উপস্থিত ছিলেন। ইত্তেফাকইউবি</s>

# %%
import numpy as np
from pathlib import Path

# Configuration
SAVE_DIR = "/content/bangla_gpt_data"
BIN_DTYPE = np.uint16  # 16-bit integers (vocab < 65536)

Path(SAVE_DIR).mkdir(parents=True, exist_ok=True)


# Create memory-mapped files for efficient loading
for split in ("train", "validation"):
    tokens = tokenized_ds[split]
    total_tokens = int(np.sum(tokens["len"], dtype=np.uint64))

    # Create memory-mapped file
    mmap = np.memmap(
        Path(SAVE_DIR) / f"{split}.bin",
        dtype=BIN_DTYPE,
        mode="w+",
        shape=(total_tokens,)
    )

    # Write tokens to file
    idx = 0
    for token_list in tokens["ids"]:
        buf = np.asarray(token_list, dtype=BIN_DTYPE)
        mmap[idx:idx+len(buf)] = buf
        idx += len(buf)

    mmap.flush()
    print(f"Saved {split}.bin – {total_tokens:,} tokens")
# Out:
# Saved train.bin – 2,313,528 tokens
# Saved validation.bin – 123,557 tokens

# %%
import json

# Save important information
meta = {
    "tokenizer": TOKENIZER,
    "vocab_size": tokenizer.vocab_size,
    "train_tokens": int(np.sum(tokenized_ds["train"]["len"])),
    "val_tokens": int(np.sum(tokenized_ds["validation"]["len"])),
    "block_size": 128,              # Model context length
    "bin_dtype": "uint16",          # Data type used for storage
}

with open(Path(SAVE_DIR) / "meta.json", "w") as f:
    json.dump(meta, f, indent=2)
